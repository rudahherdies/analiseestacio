# %%
import pandas as pd
#importando a base de dados
funcionarios_df = pd.read_csv(r'CadastroFuncionarios.csv', sep=';', decimal=',')
clientes_df = pd.read_csv(r'CadastroClientes.csv')
funcionarios_df = funcionarios_df.drop(['Estado Civil', 'Cargo'], axis=1)
display(funcionarios_df)
# Out:
#      ID Funcionário                    Nome Completo  Salario Base  Impostos  \
# 0                 1                 Gabriel Mesquita         21910   10955.0
# 1                 2         Juliana Pereira da Rocha          5404    2702.0
# 2                 3           Amanda Marques Ribeiro         16066    8033.0
# 3                 4                  Guilherme Nunez         21305   10652.5
# 4                 5                    Adelino Gomes          5098    2549.0
# ..              ...                              ...           ...       ...
# 109             143              Yuri Gomes Ferreira         10793    5396.5
# 110             144               Lucas Brum Pereira          4048    2024.0
# 111             148  Paulo César Ferreira dos Santos         24596   12298.0
# 112             149                   Fernanda Rocha          5078    2539.0
# 113             150                     Eduardo Brum         15939    7969.5
#
#      Beneficios   VT      VR            Area
# 0        4382.0  242  719.04       Operações
# 1        1080.8  154  574.56       Logística
# 2        3213.2  154  729.12  Administrativo
# 3        4261.0  220  524.16  Administrativo
# 4        1019.6  176  725.76  Administrativo
# ..          ...  ...     ...             ...
# 109      2158.6  242  514.08       Logística
# 110       809.6  198  796.32       Comercial
# 111      4919.2  242  561.12  Administrativo
# 112      1015.6  308  665.28       Comercial
# 113      3187.8  220  769.44       Comercial
#
# [114 rows x 8 columns]

# %% [markdown]
# ## Valor Total da folha salarial

# %%
funcionarios_df['Valor Total Salarial'] = funcionarios_df['Salario Base'] + funcionarios_df['Impostos'] + funcionarios_df['Beneficios']
display(funcionarios_df)
valor_total = funcionarios_df['Valor Total Salarial'].sum()
print(valor_total)
# Out:
#      ID Funcionário                    Nome Completo  Salario Base  Impostos  \
# 0                 1                 Gabriel Mesquita         21910   10955.0
# 1                 2         Juliana Pereira da Rocha          5404    2702.0
# 2                 3           Amanda Marques Ribeiro         16066    8033.0
# 3                 4                  Guilherme Nunez         21305   10652.5
# 4                 5                    Adelino Gomes          5098    2549.0
# ..              ...                              ...           ...       ...
# 109             143              Yuri Gomes Ferreira         10793    5396.5
# 110             144               Lucas Brum Pereira          4048    2024.0
# 111             148  Paulo César Ferreira dos Santos         24596   12298.0
# 112             149                   Fernanda Rocha          5078    2539.0
# 113             150                     Eduardo Brum         15939    7969.5
#
#      Beneficios   VT      VR            Area  Valor Total Salarial
# 0        4382.0  242  719.04       Operações               37247.0
# 1        1080.8  154  574.56       Logística                9186.8
# 2        3213.2  154  729.12  Administrativo               27312.2
# 3        4261.0  220  524.16  Administrativo               36218.5
# 4        1019.6  176  725.76  Administrativo                8666.6
# ..          ...  ...     ...             ...                   ...
# 109      2158.6  242  514.08       Logística               18348.1
# 110       809.6  198  796.32       Comercial                6881.6
# 111      4919.2  242  561.12  Administrativo               41813.2
# 112      1015.6  308  665.28       Comercial                8632.6
# 113      3187.8  220  769.44       Comercial               27096.3
#
# [114 rows x 9 columns]
# 2614343.3

# %%
servicos_df = pd.read_excel(r'BaseServiçosPrestados.xlsx')
clientes_df = pd.read_csv(r'CadastroClientes.csv', sep=';')
#mesclando as duas planilhas
servicos_df = servicos_df.merge(clientes_df, on='ID Cliente')
servicos_df = servicos_df.merge(funcionarios_df, on='ID Funcionário')
servicos_df['Faturamento Total'] = servicos_df['Tempo Total de Contrato (Meses)'] * servicos_df['Valor Contrato Mensal']
display(servicos_df)
display(funcionarios_df)
# Out:
#     Codigo do Servico  ID Funcionário  ID Cliente  \
# 0              OS0001              67           1
# 1              OS0002              17           2
# 2              OS0003             116           4
# 3              OS0004              37           5
# 4              OS0005             130           6
# ..                ...             ...         ...
# 232            OS0233             111         315
# 233            OS0234             124         316
# 234            OS0235              72         317
# 235            OS0236              90         319
# 236            OS0237              22         320
#
#      Tempo Total de Contrato (Meses)             Cliente  \
# 0                                 14  Teixeira Gonçalves
# 1                                 12        Souza Santos
# 2                                 14        Santos Costa
# 3                                  8         Do Monteiro
# 4                                  8         Soares Lobo
# ..                               ...                 ...
# 232                                4      Americo Bomfim
# 233                                8        Manoel Costa
# 234                                6       Gomes Machado
# 235                               14     Pereira Fazenda
# 236                               12   Americo Damasceno
#
#      Valor Contrato Mensal                     Nome Completo  Salario Base  \
# 0                      540             Carla Amiccuci Areias         12054
# 1                     1260                     Pedro Carrera         15718
# 2                     2520               Bruno Cunha Felippe         21154
# 3                     3510  Marcos Almeida Albuquerque Faria          3398
# 4                     2340           Mylena Pinheiro Mariano          5818
# ..                     ...                               ...           ...
# 232                   1575              Daniela Santos Silva          9367
# 233                   3690  Carolina Gonçalves Lixa Fontoura         12559
# 234                   2385                      Lucas Duarte         11867
# 235                   4185         Bruna Tavares Vasconcelos         12101
# 236                   2430                      Bruno Vargas         10726
#
#      Impostos  Beneficios   VT      VR            Area  Valor Total Salarial  \
# 0      6027.0      2410.8  308  829.92      Financeiro               20491.8
# 1      7859.0      3143.6  176  628.32       Logística               26720.6
# 2     10577.0      4230.8  198  792.96       Logística               35961.8
# 3      1699.0       679.6  242  540.96      Financeiro                5776.6
# 4      2909.0      1163.6  242  598.08       Comercial                9890.6
# ..        ...         ...  ...     ...             ...                   ...
# 232    4683.5      1873.4  198  554.40       Operações               15923.9
# 233    6279.5      2511.8  242  688.80       Comercial               21350.3
# 234    5933.5      2373.4  264  524.16       Logística               20173.9
# 235    6050.5      2420.2  176  591.36  Administrativo               20571.7
# 236    5363.0      2145.2  198  547.68       Comercial               18234.2
#
#      Faturamento Total
# 0                 7560
# 1                15120
# 2                35280
# 3                28080
# 4                18720
# ..                 ...
# 232               6300
# 233              29520
# 234              14310
# 235              58590
# 236              29160
#
# [237 rows x 15 columns]
#      ID Funcionário                    Nome Completo  Salario Base  Impostos  \
# 0                 1                 Gabriel Mesquita         21910   10955.0
# 1                 2         Juliana Pereira da Rocha          5404    2702.0
# 2                 3           Amanda Marques Ribeiro         16066    8033.0
# 3                 4                  Guilherme Nunez         21305   10652.5
# 4                 5                    Adelino Gomes          5098    2549.0
# ..              ...                              ...           ...       ...
# 109             143              Yuri Gomes Ferreira         10793    5396.5
# 110             144               Lucas Brum Pereira          4048    2024.0
# 111             148  Paulo César Ferreira dos Santos         24596   12298.0
# 112             149                   Fernanda Rocha          5078    2539.0
# 113             150                     Eduardo Brum         15939    7969.5
#
#      Beneficios   VT      VR            Area  Valor Total Salarial
# 0        4382.0  242  719.04       Operações               37247.0
# 1        1080.8  154  574.56       Logística                9186.8
# 2        3213.2  154  729.12  Administrativo               27312.2
# 3        4261.0  220  524.16  Administrativo               36218.5
# 4        1019.6  176  725.76  Administrativo                8666.6
# ..          ...  ...     ...             ...                   ...
# 109      2158.6  242  514.08       Logística               18348.1
# 110       809.6  198  796.32       Comercial                6881.6
# 111      4919.2  242  561.12  Administrativo               41813.2
# 112      1015.6  308  665.28       Comercial                8632.6
# 113      3187.8  220  769.44       Comercial               27096.3
#
# [114 rows x 9 columns]

# %% [markdown]
# ## Fatuamento Total

# %%
faturamento_total = servicos_df['Tempo Total de Contrato (Meses)'] * servicos_df['Valor Contrato Mensal']
print(faturamento_total.sum())
# Out:
# 5519160

# %% [markdown]
# ## Percentual de funcionários que fecharam contratos

# %%
#pegando o valor único sem duplicatas com o 'unique()'
qtd_func_contratos = len(servicos_df['ID Funcionário'].unique())
qtd_func_total = len(funcionarios_df['ID Funcionário'])
print('Percentual de funcionários que fecharam contratos {:.2%}'.format(qtd_func_contratos / qtd_func_total))
# Out:
# Percentual de funcionários que fecharam contratos 86.84%

# %% [markdown]
# ## Quantidade de contratos por área

# %%
contratos_area_df = servicos_df[['ID Funcionário']].merge(funcionarios_df[['ID Funcionário', 'Area']], on='ID Funcionário')
contratos_area_qtd = contratos_area_df['Area'].value_counts()

#plotando as informações em  um gráfico
contratos_area_qtd.plot.bar()
print(contratos_area_qtd)
# Out:
# Area
# Administrativo    63
# Operações         48
# Comercial         44
# Financeiro        42
# Logística         40
# Name: count, dtype: int64

# %% [markdown]
# ## Quantidade de funcionários por área

# %%
funcionarios_area = funcionarios_df['Area'].value_counts()
print(funcionarios_area)

#plotando a informação em um gráfico
funcionarios_area.plot.pie(figsize=(5, 5))
# Out:
# Area
# Administrativo    26
# Comercial         26
# Operações         23
# Logística         21
# Financeiro        18
# Name: count, dtype: int64
# <Axes: ylabel='count'>

# %% [markdown]
# ## Ticket Médio mensal

# %%
ticket_medio = clientes_df['Valor Contrato Mensal'].mean()
print('Valor total do Ticket Médio: R${:,.2f}'.format(ticket_medio))
# Out:
# Valor total do Ticket Médio: R$2,502.56
